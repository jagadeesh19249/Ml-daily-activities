# %% [markdown]
# # What is Binning:
#
# - Binning, also known as bucketing, is a data preprocessing technique in machine learning used to group continuous numerical variables into discrete   intervals or "bins".
#
# - Each data point is then assigned a label (or) value corresponding to the bin into which it falls.

# %% [markdown]
# ### Why do we use Binning:
# - Reduce noise in data
# - Handle outliers
# - Simplify complex data
# - Improve model intterpretablility
# - - Convert continuous -> Categories

# %% [markdown]
# ### Used in
# - Decission Trees
# - Rule-based models
# - Business analytics
# - Credit scoring, grading systems

# %% [markdown]
# ### Types of Binning:
# - Equal-width Binning(Distance Binning)
# - Equal-Frequency Binning(Quantile Binning)
# - Custom / Domain-Based Binning

# %% [markdown]
# ### 1. Equal-Width Binning (Distance Binning):
#
# - Equal-Width Binning divides the entire range of a continuous variable into a fixed number of bins, where each bin has the same width (distance).
# - This method does not consider how data is distributed inside the range. It only focuses on the minimum and maximum values.

# %% [markdown]
# ### Formula :
# - Bin width = (max-min)/k

# %% [markdown]
# ### Example
# [18,22,25,30,35,40,45,50]
#
# min=18
#
# max=50
#
# k=4
#
# Where,k=number of bins

# %% [markdown]
# Bin_width=(50-18)/4=32/4=8

# %% [markdown]
# ### Bins:
# - 18-26
# - 26-34
# - 34-42
# - 42-50

# %% [markdown]
# ### Key Points
# - Count difference
# - Range Same

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.DataFrame({
    "age":[18,22,25,30,35,40,45,50]
})
data
# Out:
#    age
# 0   18
# 1   22
# 2   25
# 3   30
# 4   35
# 5   40
# 6   45
# 7   50

# %% [markdown]
# # Equal width

# %%
data["age_bin"]= pd.cut(data["age"], bins=3)
data
# Out:
#    age           age_bin
# 0   18  (17.968, 28.667]
# 1   22  (17.968, 28.667]
# 2   25  (17.968, 28.667]
# 3   30  (28.667, 39.333]
# 4   35  (28.667, 39.333]
# 5   40    (39.333, 50.0]
# 6   45    (39.333, 50.0]
# 7   50    (39.333, 50.0]

# %%
plt.hist(data["age"],bins=4)
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Equal_width Binning Using")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(data["age"],bins=3)
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Equal_width Binning Using")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Equal-Frequency Binning (Quantile Binning):
#
# - Equal-Frequency Binning divides the data into bins such that each bin contains approximately the same number of observations.
#
# - This method uses the data distribution and is based on quantiles (percentiles).

# %% [markdown]
# ### Formula:
# - Total observations = n
# - number of bins = k

# %% [markdown]
# ### observations per bin:
# n/k

# %% [markdown]
# ### Example
# [18,22,25,30,35,40,45,50]

# %% [markdown]
# ### observations per bin:
# 8/4 = 2

# %% [markdown]
# ### Bins
# - First 2 values -> Bin 1
# - Next 2 values ->Bin 2
# - First 2 values -> Bin 3
# - Next 2 values ->Bin 4

# %% [markdown]
# ### key points
# - count same
# - range difference

# %%
data["age_frequency_bin"]= pd.qcut(data["age"],q=4)
data
# Out:
#    age           age_bin age_frequency_bin
# 0   18  (17.968, 28.667]   (17.999, 24.25]
# 1   22  (17.968, 28.667]   (17.999, 24.25]
# 2   25  (17.968, 28.667]     (24.25, 32.5]
# 3   30  (28.667, 39.333]     (24.25, 32.5]
# 4   35  (28.667, 39.333]     (32.5, 41.25]
# 5   40    (39.333, 50.0]     (32.5, 41.25]
# 6   45    (39.333, 50.0]     (41.25, 50.0]
# 7   50    (39.333, 50.0]     (41.25, 50.0]

# %%
plt.hist(data["age"],bins=4)
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Age frequency Binning Using")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
bin_min=data["age"].groupby(data["age_frequency_bin"]).min()
bin_min
# Out:
# C:\Users\jagad\AppData\Local\Temp\ipykernel_1384\3652160047.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   bin_min=data["age"].groupby(data["age_frequency_bin"]).min()
# age_frequency_bin
# (17.999, 24.25]    18
# (24.25, 32.5]      25
# (32.5, 41.25]      35
# (41.25, 50.0]      45
# Name: age, dtype: int64

# %%
bin_min=data["age"].groupby(data["age_frequency_bin"]).max()
bin_min
# Out:
# C:\Users\jagad\AppData\Local\Temp\ipykernel_1384\3588345739.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   bin_min=data["age"].groupby(data["age_frequency_bin"]).max()
# age_frequency_bin
# (17.999, 24.25]    22
# (24.25, 32.5]      30
# (32.5, 41.25]      40
# (41.25, 50.0]      50
# Name: age, dtype: int64

# %%
bin_min=data["age"].groupby(data["age_frequency_bin"]).median()
bin_min
# Out:
# C:\Users\jagad\AppData\Local\Temp\ipykernel_1384\968832029.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   bin_min=data["age"].groupby(data["age_frequency_bin"]).median()
# age_frequency_bin
# (17.999, 24.25]    20.0
# (24.25, 32.5]      27.5
# (32.5, 41.25]      37.5
# (41.25, 50.0]      47.5
# Name: age, dtype: float64

# %% [markdown]
# # custom/domain-based binning
# - Custom binning uses predifined bin boundaries based an domain knowledge ,business rules,or external standards.
# - this method is not data-driven, but context-driven
# ### Example(Age gruops)
# #### Bins
# 18-25->Young
#
# 25-60->Adult
#
# 60-100->senior

# %%
custom_bins=[17,25,35,50]
labels = ["Young","Adult","Senior"]

bins= pd.cut(data["age"], bins=custom_bins,labels=labels)
bins
# Out:
# 0     Young
# 1     Young
# 2     Young
# 3     Adult
# 4     Adult
# 5    Senior
# 6    Senior
# 7    Senior
# Name: age, dtype: category
# Categories (3, object): ['Young' < 'Adult' < 'Senior']

# %%
plt.hist(bins,bins=4)
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Age frequency Binning Using")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
