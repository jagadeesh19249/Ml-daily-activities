# %%
l=[]
print(l)
print(type(l))
# Out:
# []
# <class 'list'>

# %%
l=[1,2,3,4,5]
l.append(34)
print(l)
# Out:
# [1, 2, 3, 4, 5, 34]

# %%
l=[1,2,3,4,5]
l.remove(3)
print(l)
# Out:
# [1, 2, 4, 5]

# %%
l=[1,2,3,4,5]
l.pop()
print(l)
# Out:
# [1, 2, 3, 4]

# %%
l=[1,2,3,4,5]
print(len(l))
# Out:
# 5

# %%
l=[1,2,3,4,5]
print(max(l))
# Out:
# 5

# %%
l=[1,2,3,4,5]
print(min(l))
# Out:
# 1

# %%
#files
f= open('jk.txt','a')
print('File name :',f.name)
print('File mode :',f.mode)
print(f.readable())
print(f.writable())
print(f.closed)
f.close()
print(f.closed)
# Out:
# File name : jk.txt
# File mode : a
# False
# True
# False
# True

# %%
#with statement

with open("jk.txt","r") as file:
    content = file.read()
print(content)
# Out:
# aditya degree college

# %%
with open("jk.txt","r") as file:
    content = file.read(10)
print(content)
# Out:
# aditya deg

# %%
with open("jk.txt","r") as file:
    content = file.readline()
print(content)
# Out:
# ajay Karthik

# %%
with open("jk.txt","r") as file:
    content = file.readlines()
print(content)
# Out:
# ['ajay Karthik\n', 'swami\n', 'banti\n']

# %%
#writing to a file
with open("jk.txt","w") as file:
     file.write("aditya degree college")

# %%
l=["aditya\n","degree\n","college\n","ap\n","kakinada\n"]
with open("jk.txt","w") as file:
     file.writelines(l)

# %%
#appending to a file
with open("jk.txt","a") as file:
     file.write("533345")

# %%
#writing to a csv file
import csv
with open("data.csv","w",newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Name","age","city"])
    writer.writerow(["ajay","20","kkd"])
    writer.writerow(["deevan","14","samarlakotta"])

# %%
#print the data
import csv
with open("data.csv","r") as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'age', 'city']
# ['ajay', '20', 'kkd']
# ['deevan', '14', 'samarlakotta']
